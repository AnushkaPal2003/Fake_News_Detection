# %% [markdown]
# # Fake News Detection — Training on Colab GPU
#
# Before running: **Runtime → Change runtime type → T4 GPU → Save**

# %% [markdown]
# ## 1. Clone repo

# %%
# !git clone https://github.com/AnushkaPal2003/Fake_News_Detection
# %cd Fake_News_Detection
# Out:
# Cloning into 'Fake_News_Detection'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 26 (delta 7), reused 24 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (26/26), 11.78 KiB | 11.78 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# /content/Fake_News_Detection

# %% [markdown]
# ## 2. Install dependencies

# %%
# !pip install -r requirements.txt --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 52.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 107.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 96.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 84.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 117.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.7/264.7 kB 28.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 124.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.0/212.0 kB 22.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.3/99.3 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 70.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.2/132.2 kB 16.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.6/954.6 kB 66.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.9/214.9 kB 24.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 8.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyopenssl 26.3.0 requires cryptography<50,>=49.0.0, but you have cryptography 48.0.1 which is incompatible.

# %% [markdown]
# ## 3. Mount Google Drive and copy dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

import shutil, os
os.makedirs('data', exist_ok=True)
shutil.copy('/content/drive/MyDrive/data/True.csv', 'data/True.csv')
shutil.copy('/content/drive/MyDrive/data/Fake.csv', 'data/Fake.csv')
print('Dataset copied.')
# Out:
# Mounted at /content/drive
# Dataset copied.

# %% [markdown]
# ## 4. Verify GPU is active

# %%
import tensorflow as tf
print("GPU Available:", tf.config.list_physical_devices('GPU'))
# Out:
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 5. Point MLflow tracking at Drive (so runs survive session end)

# %%
import mlflow
mlflow.set_tracking_uri("sqlite:////content/drive/MyDrive/mlflow.db")

# %% [markdown]
# ## 6. Run training (RNN, LSTM, GRU + TF-IDF baseline)

# %%
from src.train import run_training
results = run_training(data_dir="data")
# Out:
# Preprocessing data...
# Train size: 35911, Test size: 8978
# Vocab size: 190631
#
# Training Word2Vec embeddings...
# Word2Vec trained on 35911 documents
# Words found in Word2Vec: 19998/20000
#
# --- Training RNN ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 22s 33ms/step - accuracy: 0.5543 - loss: 0.6932 - val_accuracy: 0.5885 - val_loss: 0.6628
# Epoch 2/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.5819 - loss: 0.6661 - val_accuracy: 0.6036 - val_loss: 0.6486
# Epoch 3/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.6044 - loss: 0.6500 - val_accuracy: 0.7294 - val_loss: 0.5552
# Epoch 4/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.6447 - loss: 0.6255 - val_accuracy: 0.6058 - val_loss: 0.6484
# Epoch 5/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.5992 - loss: 0.6523 - val_accuracy: 0.6141 - val_loss: 0.6363
# Epoch 6/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.6091 - loss: 0.6441 - val_accuracy: 0.6225 - val_loss: 0.6285
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2026/07/09 11:53:03 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/07/09 11:53:03 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# RNN — Accuracy: 0.7262 | F1: 0.7129 | ROC-AUC: 0.7816
#
# --- Training LSTM ---
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.8540 - loss: 0.3749 - val_accuracy: 0.9045 - val_loss: 0.3177
# Epoch 2/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9043 - loss: 0.2729 - val_accuracy: 0.9201 - val_loss: 0.2439
# Epoch 3/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9379 - loss: 0.1925 - val_accuracy: 0.9574 - val_loss: 0.1730
# Epoch 4/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9454 - loss: 0.1842 - val_accuracy: 0.9772 - val_loss: 0.0953
# Epoch 5/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9662 - loss: 0.1207 - val_accuracy: 0.9752 - val_loss: 0.0745
# Epoch 6/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9724 - loss: 0.1102 - val_accuracy: 0.9833 - val_loss: 0.0616
# Epoch 7/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9716 - loss: 0.1025 - val_accuracy: 0.9839 - val_loss: 0.0556
# Epoch 8/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9748 - loss: 0.0772 - val_accuracy: 0.9925 - val_loss: 0.0267
# Epoch 9/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.9864 - loss: 0.0506 - val_accuracy: 0.9933 - val_loss: 0.0276
# Epoch 10/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.9886 - loss: 0.0390 - val_accuracy: 0.9919 - val_loss: 0.0216
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2026/07/09 11:54:54 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/07/09 11:54:54 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# LSTM — Accuracy: 0.9932 | F1: 0.9929 | ROC-AUC: 0.9997
#
# --- Training GRU ---
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.7592 - loss: 0.4852 - val_accuracy: 0.9555 - val_loss: 0.1814
# Epoch 2/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.8871 - loss: 0.3210 - val_accuracy: 0.9246 - val_loss: 0.2418
# Epoch 3/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.9243 - loss: 0.2536 - val_accuracy: 0.8942 - val_loss: 0.2537
# Epoch 4/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.9639 - loss: 0.1170 - val_accuracy: 0.9939 - val_loss: 0.0264
# Epoch 5/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9909 - loss: 0.0405 - val_accuracy: 0.9961 - val_loss: 0.0192
# Epoch 6/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.9935 - loss: 0.0280 - val_accuracy: 0.9967 - val_loss: 0.0145
# Epoch 7/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9950 - loss: 0.0204 - val_accuracy: 0.9983 - val_loss: 0.0087
# Epoch 8/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.9960 - loss: 0.0162 - val_accuracy: 0.9986 - val_loss: 0.0072
# Epoch 9/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9967 - loss: 0.0143 - val_accuracy: 0.9986 - val_loss: 0.0079
# Epoch 10/10
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9975 - loss: 0.0109 - val_accuracy: 0.9986 - val_loss: 0.0073
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2026/07/09 11:56:34 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/07/09 11:56:34 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# GRU — Accuracy: 0.9984 | F1: 0.9984 | ROC-AUC: 1.0000
#
# --- Training Baseline (TF-IDF + Logistic Regression) ---
# Baseline — Accuracy: 0.9922 | F1: 0.9918 | ROC-AUC: 0.9995
#
# === Final Results ===
# RNN: Accuracy=0.7262 | F1=0.7129 | ROC-AUC=0.7816
# LSTM: Accuracy=0.9932 | F1=0.9929 | ROC-AUC=0.9997
# GRU: Accuracy=0.9984 | F1=0.9984 | ROC-AUC=1.0
# TFIDF_LR: Accuracy=0.9922 | F1=0.9918 | ROC-AUC=0.9995

# %% [markdown]
# ## 7. Zip and download artifacts (models, tokenizer, embeddings, plots)

# %%
# !zip -r artifacts.zip artifacts/
from google.colab import files
files.download('artifacts.zip')
# Out:
#   adding: artifacts/ (stored 0%)
#   adding: artifacts/word2vec.model (deflated 10%)
#   adding: artifacts/lr_model.pkl (deflated 4%)
#   adding: artifacts/models/ (stored 0%)
#   adding: artifacts/models/gru_model.h5 (deflated 8%)
#   adding: artifacts/models/lstm_model.h5 (deflated 8%)
#   adding: artifacts/models/rnn_model.h5 (deflated 8%)
#   adding: artifacts/embedding_matrix.npy (deflated 46%)
#   adding: artifacts/tfidf.pkl (deflated 69%)
#   adding: artifacts/results.json (deflated 63%)
#   adding: artifacts/tokenizer.pkl (deflated 59%)
