# %% [markdown]
# # Fake News Detection — Training on Colab GPU
#
# Before running: **Runtime → Change runtime type → T4 GPU → Save**

# %% [markdown]
# ## 1. Clone repo

# %%
# !git clone https://github.com/AnushkaPal2003/YOUR-REPO-NAME.git
# %cd YOUR-REPO-NAME

# %% [markdown]
# ## 2. Install dependencies

# %%
# !pip install -r requirements.txt --quiet

# %% [markdown]
# ## 3. Mount Google Drive and copy dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

import shutil, os
os.makedirs('data', exist_ok=True)
# Update this path to match where you uploaded True.csv / Fake.csv in your Drive
shutil.copy('/content/drive/MyDrive/fake-news-data/True.csv', 'data/True.csv')
shutil.copy('/content/drive/MyDrive/fake-news-data/Fake.csv', 'data/Fake.csv')
print('Dataset copied.')

# %% [markdown]
# ## 4. Verify GPU is active

# %%
import tensorflow as tf
print("GPU Available:", tf.config.list_physical_devices('GPU'))

# %% [markdown]
# ## 5. Point MLflow tracking at Drive (so runs survive session end)

# %%
import mlflow
os.makedirs('/content/drive/MyDrive/mlruns', exist_ok=True)
mlflow.set_tracking_uri("file:/content/drive/MyDrive/mlruns")

# %% [markdown]
# ## 6. Run training (RNN, LSTM, GRU + TF-IDF baseline)

# %%
from src.train import run_training
results = run_training(data_dir="data")

# %% [markdown]
# ## 7. Zip and download artifacts (models, tokenizer, embeddings, plots)

# %%
# !zip -r artifacts.zip artifacts/
from google.colab import files
files.download('artifacts.zip')
